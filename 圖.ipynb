# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pip install opencv-python
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#     --------------------------------------- 0.5/39.5 MB 4.2 MB/s eta 0:00:10
#    - -------------------------------------- 1.0/39.5 MB 3.0 MB/s eta 0:00:14
#    - -------------------------------------- 1.8/39.5 MB 3.4 MB/s eta 0:00:12
#    -- ------------------------------------- 2.6/39.5 MB 3.6 MB/s eta 0:00:11
#    --- ------------------------------------ 3.7/39.5 MB 3.8 MB/s eta 0:00:10
#    ---- ----------------------------------- 4.7/39.5 MB 3.9 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.5/39.5 MB 3.9 MB/s eta 0:00:09
#    ------ --------------------------------- 6.6/39.5 MB 4.0 MB/s eta 0:00:09
#    ------- -------------------------------- 7.3/39.5 MB 4.0 MB/s eta 0:00:08
#    -------- ------------------------------- 8.1/39.5 MB 4.1 MB/s eta 0:00:08
#    --------- ------------------------------ 9.2/39.5 MB 4.1 MB/s eta 0:00:08
# ...

# %%
import numpy as np
import cv2
face_cascade = cv2.CascadeClassifier(r"C:\Users\julia\Desktop\haarcascade_frontalcatface_extended.xml")
eye_cascade = cv2.CascadeClassifier(r"C:\Users\julia\Desktop\haarcascade_eye.xml")
img = cv2.imread(r"C:\Users\julia\Desktop\ooo.png")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
plt.show()

# %%
import random
font=cv2.FONT_HERSHEY_SIMPLEX
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    cv2.putText(img, str(random.randrange(20,30)), (x+(w/2)-18, y-10), font, 1, (14, 201, 255), 2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
cv2.imshow('img',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#makeupandbeauty.com

# %%
# revised an error
TypeError: intergel argument expected, got float
將 (w/2) 改為 (w//2)
# Out:
#   Cell In[13], line 2
#     TypeError: intergel argument expected, got float
#                         ^
# SyntaxError: invalid syntax
