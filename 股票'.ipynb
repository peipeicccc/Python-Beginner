# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\julia\anaconda3\lib\site-packages (0.2.55)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\julia\anaconda3\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\julia\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\julia\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\julia\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\julia\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\julia\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\julia\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\julia\anaconda3\lib\site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\julia\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\julia\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\julia\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\julia\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\julia\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\julia\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\julia\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\julia\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2024.8.30)
# Requirement already satisfied: six>=1.5 in c:\users\julia\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)

# %%
import yfinance as yf
import pandas as pd

# %%
start_date='1990-01-01'
end_date='2025-04-04'

# %%
ticker='AMZN'

# %%
data=yf.download(ticker,period='10y',interval='1d',auto_adjust=False)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
# Price       Adj Close      Close       High        Low       Open    Volume
# Ticker           AMZN       AMZN       AMZN       AMZN       AMZN      AMZN
# Date
# 2015-04-06  18.851999  18.851999  19.010000  18.468000  18.504999  61014000
# 2015-04-07  18.720501  18.720501  18.965500  18.701500  18.807501  39098000
# 2015-04-08  19.059999  19.059999  19.079000  18.732500  18.733000  52728000
# 2015-04-09  19.177000  19.177000  19.221001  18.940001  19.033001  47846000
# 2015-04-10  19.132500  19.132500  19.356001  19.066000  19.215500  51470000

# %%
data.tail()
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            AMZN        AMZN        AMZN        AMZN        AMZN
# Date
# 2025-03-31  190.259995  190.259995  191.330002  184.399994  188.190002
# 2025-04-01  192.169998  192.169998  193.929993  187.199997  187.860001
# 2025-04-02  196.009995  196.009995  198.339996  187.660004  187.660004
# 2025-04-03  178.410004  178.410004  184.130005  176.919998  183.000000
# 2025-04-04  171.000000  171.000000  178.139999  166.000000  167.149994
#
# Price          Volume
# Ticker           AMZN
# Date
# 2025-03-31   63547600
# 2025-04-01   41267300
# 2025-04-02   53679200
# 2025-04-03   95553600
# 2025-04-04  122951300

# %%
# Import matplotlib for plotting
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Plot adjusted close price data
data['Adj Close'].plot(figsize=(10,7))
plt.title("Adjusted Close Price of%s" %ticker,fontsize=16)
plt.ylabel('Price',fontsize=14)
plt.xlabel('year',fontsize=14)
plt.grid(which='major', color='k', linestyle='-', linewidth=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import packages
import yfinance as yf
import pandas as pd

# %%
## Set the start and end date
start_date = '1990-01-01'
end_date = '2025-04-04'

# %%
# Define the ticker list
tickers_list=['AMZN','IBM','MSFT']

# %%
# Create placeholder for data
data = pd.DataFrame(columns=tickers_list)

# %%
# Fetch the data
for ticker in tickers_list:
    data[ticker] = yf.download(ticker,start_date,end_date,auto_adjust=False)['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                 AMZN        IBM      MSFT
# Date
# 1997-05-15  0.097917  21.584326  8.991260
# 1997-05-16  0.086458  21.103292  8.861713
# 1997-05-19  0.085417  20.948128  8.837726
# 1997-05-20  0.081771  21.568817  9.144790
# 1997-05-21  0.071354  21.739498  9.240751

# %%
import matplotlib.pyplot as plt

# %%
data.plot(figsize=(10, 7))
plt.legend()
plt.title("Adjusted Close Price",fontsize=16)
plt.ylabel('Price',fontsize=14)
plt.xlabel('Year',fontsize=14)
plt.grid(which='major', color='k', linestyle='-', linewidth=0.5)
plt.show()
